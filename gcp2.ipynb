# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------
# absl-py                                  2.1.0
# aiofiles                                 22.1.0
# aiohappyeyeballs                         2.4.4
# aiohttp                                  3.11.11
# aiohttp-cors                             0.7.0
# aiosignal                                1.3.2
# aiosqlite                                0.20.0
# annotated-types                          0.7.0
# ansicolors                               1.1.8
# anyio                                    4.7.0
# archspec                                 0.2.3
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asttokens                                3.0.0
# async-timeout                            5.0.1
# atpublic                                 4.1.0
# attrs                                    24.3.0
# babel                                    2.16.0
# backports.tarfile                        1.2.0
# beautifulsoup4                           4.12.3
# bidict                                   0.23.1
# bigframes                                1.9.0
# bleach                                   6.2.0
# blessed                                  1.20.0
# boltons                                  24.0.0
# bq_stats                                 1.0
# Brotli                                   1.1.0
# cachetools                               5.5.0
# certifi                                  2024.12.14
# cffi                                     1.17.1
# charset-normalizer                       3.4.0
# click                                    8.1.8
# cloud-tpu-client                         0.10
# cloudpickle                              3.1.0
# colorama                                 0.4.6
# colorful                                 0.5.6
# comm                                     0.2.2
# conda                                    24.11.2
# conda-libmamba-solver                    24.11.1
# conda-package-handling                   2.4.0
# conda_package_streaming                  0.11.0
# contourpy                                1.3.1
# cryptography                             44.0.0
# cupy-cuda12x                             13.3.0
# cycler                                   0.12.1
# dacite                                   1.8.1
# db-dtypes                                1.3.1
# debugpy                                  1.8.11
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.15
# distlib                                  0.3.9
# distro                                   1.9.0
# dm-tree                                  0.1.8
# docker                                   7.1.0
# docstring_parser                         0.16
# entrypoints                              0.4
# exceptiongroup                           1.2.2
# executing                                2.1.0
# Farama-Notifications                     0.0.4
# fastapi                                  0.115.6
# fastjsonschema                           2.21.1
# fastrlock                                0.8.3
# filelock                                 3.16.1
# fonttools                                4.55.3
# fqdn                                     1.5.1
# frozendict                               2.4.6
# frozenlist                               1.5.0
# fsspec                                   2024.12.0
# gcsfs                                    2024.12.0
# geopandas                                1.0.1
# gitdb                                    4.0.11
# GitPython                                3.1.43
# google-api-core                          1.34.1
# google-api-python-client                 1.8.0
# google-auth                              2.37.0
# google-auth-httplib2                     0.2.0
# google-auth-oauthlib                     1.2.1
# google-cloud-aiplatform                  1.75.0
# google-cloud-artifact-registry           1.14.0
# google-cloud-bigquery                    3.25.0
# google-cloud-bigquery-connection         1.17.0
# google-cloud-bigquery-storage            2.27.0
# google-cloud-core                        2.4.1
# google-cloud-datastore                   1.15.5
# google-cloud-functions                   1.19.0
# google-cloud-iam                         2.17.0
# google-cloud-language                    2.16.0
# google-cloud-monitoring                  2.24.0
# google-cloud-resource-manager            1.14.0
# google-cloud-storage                     2.14.0
# google-crc32c                            1.6.0
# google-resumable-media                   2.7.2
# googleapis-common-protos                 1.66.0
# gpustat                                  1.0.0
# greenlet                                 3.1.1
# grpc-google-iam-v1                       0.13.1
# grpcio                                   1.68.1
# grpcio-status                            1.48.2
# gymnasium                                1.0.0
# h11                                      0.14.0
# h2                                       4.1.0
# hpack                                    4.0.0
# htmlmin                                  0.1.12
# httplib2                                 0.22.0
# httptools                                0.6.4
# humanize                                 4.11.0
# hyperframe                               6.0.1
# ibis-framework                           8.0.0
# idna                                     3.10
# ImageHash                                4.3.1
# imageio                                  2.36.1
# importlib_metadata                       8.4.0
# ipykernel                                6.29.5
# ipython                                  8.21.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipywidgets                               8.1.5
# isoduration                              20.11.0
# jaraco.classes                           3.4.0
# jaraco.context                           6.0.1
# jaraco.functools                         4.1.0
# jedi                                     0.19.2
# jeepney                                  0.8.0
# jellyfish                                1.1.3
# Jinja2                                   3.1.5
# joblib                                   1.4.2
# json5                                    0.10.0
# jsonpatch                                1.33
# jsonpointer                              3.0.0
# jsonschema                               4.23.0
# jsonschema-specifications                2024.10.1
# jupyter_client                           7.4.9
# jupyter_core                             5.7.2
# jupyter-events                           0.11.0
# jupyter_server                           2.15.0
# jupyter_server_fileid                    0.9.3
# jupyter-server-mathjax                   0.2.6
# jupyter_server_terminals                 0.5.3
# jupyter_server_ydoc                      0.8.0
# jupyter-ydoc                             0.2.5
# jupyterlab                               3.6.8
# jupyterlab_pygments                      0.3.0
# jupyterlab_server                        2.27.3
# jupyterlab_widgets                       3.0.13
# keyring                                  25.5.0
# keyrings.google-artifactregistry-auth    1.1.2
# kfp                                      2.5.0
# kfp-pipeline-spec                        0.2.2
# kfp-server-api                           2.0.5
# kiwisolver                               1.4.8
# kubernetes                               26.1.0
# lazy_loader                              0.4
# libmambapy                               2.0.5
# linkify-it-py                            2.0.3
# llvmlite                                 0.43.0
# lz4                                      4.3.3
# markdown-it-py                           3.0.0
# MarkupSafe                               3.0.2
# matplotlib                               3.9.4
# matplotlib-inline                        0.1.7
# mdit-py-plugins                          0.4.2
# mdurl                                    0.1.2
# memray                                   1.15.0
# menuinst                                 2.2.0
# mistune                                  3.0.2
# more-itertools                           10.5.0
# msgpack                                  1.1.0
# multidict                                6.1.0
# multimethod                              1.12
# multipledispatch                         1.0.0
# nbclassic                                1.1.0
# nbclient                                 0.10.2
# nbconvert                                7.16.4
# nbdime                                   3.2.0
# nbformat                                 5.10.4
# nest-asyncio                             1.6.0
# networkx                                 3.4.2
# notebook                                 6.5.7
# notebook_shim                            0.2.4
# numba                                    0.60.0
# numpy                                    1.26.4
# nvidia-ml-py                             11.495.46
# oauth2client                             4.1.3
# oauthlib                                 3.2.2
# opencensus                               0.11.4
# opencensus-context                       0.1.3
# opentelemetry-api                        1.27.0
# opentelemetry-exporter-otlp              1.27.0
# opentelemetry-exporter-otlp-proto-common 1.27.0
# opentelemetry-exporter-otlp-proto-grpc   1.27.0
# opentelemetry-exporter-otlp-proto-http   1.27.0
# opentelemetry-proto                      1.27.0
# opentelemetry-sdk                        1.27.0
# opentelemetry-semantic-conventions       0.48b0
# overrides                                7.7.0
# packaging                                24.2
# pandas                                   2.2.3
# pandas-profiling                         3.6.6
# pandocfilters                            1.5.1
# papermill                                2.6.0
# parso                                    0.8.4
# parsy                                    2.1
# patsy                                    1.0.1
# pexpect                                  4.9.0
# phik                                     0.12.4
# pillow                                   11.0.0
# pip                                      24.3.1
# platformdirs                             4.3.6
# plotly                                   5.24.1
# pluggy                                   1.5.0
# prettytable                              3.12.0
# prometheus_client                        0.21.1
# prompt_toolkit                           3.0.48
# propcache                                0.2.1
# proto-plus                               1.25.0
# protobuf                                 3.20.3
# psutil                                   5.9.3
# ptyprocess                               0.7.0
# pure_eval                                0.2.3
# py-spy                                   0.4.0
# pyarrow                                  15.0.2
# pyarrow-hotfix                           0.6
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.1
# pycosat                                  0.6.6
# pycparser                                2.22
# pydantic                                 2.10.4
# pydantic_core                            2.27.2
# pydata-google-auth                       1.9.0
# Pygments                                 2.18.0
# pyogrio                                  0.10.0
# pyOpenSSL                                24.3.0
# pyparsing                                3.2.0
# pyproj                                   3.7.0
# PySocks                                  1.7.1
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.0.1
# python-json-logger                       3.2.1
# pytz                                     2024.2
# PyWavelets                               1.8.0
# PyYAML                                   6.0.2
# pyzmq                                    26.2.0
# ray                                      2.40.0
# referencing                              0.35.1
# requests                                 2.32.3
# requests-oauthlib                        2.0.0
# requests-toolbelt                        0.10.1
# retrying                                 1.3.4
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.9.4
# rpds-py                                  0.22.3
# rsa                                      4.9
# ruamel.yaml                              0.18.6
# ruamel.yaml.clib                         0.2.8
# scikit-image                             0.25.0
# scikit-learn                             1.6.0
# scipy                                    1.13.1
# seaborn                                  0.13.2
# SecretStorage                            3.3.3
# Send2Trash                               1.8.3
# setuptools                               75.6.0
# shapely                                  2.0.6
# shellingham                              1.5.4
# six                                      1.17.0
# smart-open                               7.1.0
# smmap                                    5.0.1
# sniffio                                  1.3.1
# soupsieve                                2.6
# SQLAlchemy                               2.0.36
# sqlglot                                  20.11.0
# sqlparse                                 0.5.3
# stack-data                               0.6.3
# starlette                                0.41.3
# statsmodels                              0.14.4
# tabulate                                 0.9.0
# tenacity                                 9.0.0
# tensorboardX                             2.6.2.2
# terminado                                0.18.1
# textual                                  1.0.0
# threadpoolctl                            3.5.0
# tifffile                                 2024.12.12
# tinycss2                                 1.4.0
# tomli                                    2.2.1
# toolz                                    0.12.1
# tornado                                  6.4.2
# tqdm                                     4.67.1
# traitlets                                5.14.3
# truststore                               0.10.0
# typeguard                                4.4.1
# typer                                    0.15.1
# types-python-dateutil                    2.9.0.20241206
# typing_extensions                        4.12.2
# tzdata                                   2024.2
# uc-micro-py                              1.0.3
# uri-template                             1.3.0
# uritemplate                              3.0.1
# urllib3                                  1.26.20
# uvicorn                                  0.34.0
# uvloop                                   0.21.0
# virtualenv                               20.28.0
# visions                                  0.7.6
# watchfiles                               1.0.3
# wcwidth                                  0.2.13
# webcolors                                24.11.1
# webencodings                             0.5.1
# websocket-client                         1.8.0
# websockets                               14.1
# wheel                                    0.45.1
# widgetsnbextension                       4.0.13
# wordcloud                                1.9.4
# wrapt                                    1.17.0
# y-py                                     0.6.2
# yarl                                     1.18.3
# ydata-profiling                          4.12.1
# ypy-websocket                            0.8.4
# zipp                                     3.21.0
# zstandard                                0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    tree_id    legal_status                                     species  \
# 0    30483  Permitted Site                                  Tree(s) ::
# 1    45997  Permitted Site                                  Tree(s) ::
# 2    48142  Permitted Site                                  Tree(s) ::
# 3    48199  Permitted Site                                  Tree(s) ::
# 4    48308  Permitted Site                                  Tree(s) ::
# 5    66343  Permitted Site                                  Tree(s) ::
# 6    48349  Permitted Site                                  Tree(s) ::
# 7    45863  Permitted Site                                  Tree(s) ::
# 8    34124  Permitted Site  Arbutus 'Marina' :: Hybrid Strawberry Tree
# 9    44909  Permitted Site                                  Tree(s) ::
#
#   address  site_order                     site_info plant_type care_taker  \
# 0    None           4  Sidewalk: Curb side : Cutout       Tree    Private
# 1    None         115  Sidewalk: Curb side : Cutout       Tree    Private
# 2    None         252  Sidewalk: Curb side : Cutout       Tree    Private
# 3    None          58  Sidewalk: Curb side : Cutout       Tree    Private
# 4    None         174  Sidewalk: Curb side : Cutout       Tree    Private
# 5    None           1  Sidewalk: Curb side : Cutout       Tree    Private
# 6    None         152  Sidewalk: Curb side : Cutout       Tree    Private
# 7    None          85  Sidewalk: Curb side : Cutout       Tree    Private
# 8    None           1  Sidewalk: Curb side : Cutout       Tree    Private
# 9    None         132  Sidewalk: Curb side : Cutout       Tree    Private
#
#   care_assistant                plant_date   dbh plot_size  \
# 0           None 1956-09-05 12:00:00+00:00  None      None
# 1           None 2001-12-06 12:00:00+00:00  None      None
# 2           None 2002-07-17 12:00:00+00:00  None      None
# 3           None 2002-07-17 12:00:00+00:00  None      None
# 4           None 2002-07-17 12:00:00+00:00  None      None
# 5           None 1990-12-10 12:00:00+00:00  None      None
# 6           None 2002-07-17 12:00:00+00:00  None      None
# 7           None 2001-12-06 12:00:00+00:00  None      None
# 8           None 1997-07-05 12:00:00+00:00  None      None
# 9           None 2001-04-25 12:00:00+00:00  None      None
#
#           permit_notes  x_coordinate  y_coordinate  latitude  longitude  \
# 0    Permit Number 147           NaN           NaN       NaN        NaN
# 1  Permit Number 44451           NaN           NaN       NaN        NaN
# 2  Permit Number 45761           NaN           NaN       NaN        NaN
# 3  Permit Number 45761           NaN           NaN       NaN        NaN
# 4  Permit Number 45761           NaN           NaN       NaN        NaN
# 5  Permit Number 29464           NaN           NaN       NaN        NaN
# 6  Permit Number 45761           NaN           NaN       NaN        NaN
# 7  Permit Number 44451           NaN           NaN       NaN        NaN
# 8  Permit Number 37982           NaN           NaN       NaN        NaN
# 9  Permit Number 43922           NaN           NaN       NaN        NaN
#
#   location
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None

# %%
# %%bigquery df_tree
# SELECT species,count(*) as num_trees,min(plant_date) as min_plant_date,max(plant_date) as max_plant_date
# FROM `bigquery-public-data.san_francisco_trees.street_trees`
# group by species
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_tree
# Out:
#                                                species  num_trees  \
# 0                                           Tree(s) ::      11815
# 1           Arbutus 'Marina' :: Hybrid Strawberry Tree       5824
# 2                Lophostemon confertus :: Brisbane Box      10307
# 3        Metrosideros excelsa :: New Zealand Xmas Tree       8913
# 4    Ceanothus 'Ray Hartman' :: California Lilac 'R...        369
# ..                                                 ...        ...
# 580  Viburnum odoratissimum var. awabuki :: Sweet v...          6
# 581                 Yucca aloifolia :: Spanish bayonet          1
# 582                 Rhopalostylis sapida :: Nikau palm          1
# 583  Callistemon salignus :: White flowering bottle...          1
# 584                 Macadamia tetraphylla :: Macadamia          1
#
#                min_plant_date            max_plant_date
# 0   1955-09-19 12:00:00+00:00 2024-04-24 07:00:00+00:00
# 1   1956-02-06 12:00:00+00:00 2024-08-21 12:00:00+00:00
# 2   1956-05-11 12:00:00+00:00 2025-01-09 12:00:00+00:00
# 3   1956-06-14 12:00:00+00:00 2024-07-01 12:00:00+00:00
# 4   1969-12-18 12:00:00+00:00 2024-06-13 12:00:00+00:00
# ..                        ...                       ...
# 580                       NaT                       NaT
# 581                       NaT                       NaT
# 582                       NaT                       NaT
# 583                       NaT                       NaT
# 584                       NaT                       NaT
#
# [585 rows x 4 columns]
